# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'originated', 'of', 'as', 'term']

# %%
print(batch)
print(labels)
# Out:
# [12 12 12 12  6  6  6  6]
# [[   6]
#  [ 195]
#  [5234]
#  [3081]
#  [3081]
#  [   2]
#  [  12]
#  [ 195]]

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run() # Initially   tf.global_variables_initializer().run()  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Average loss at step 0: 8.267457
# Nearest to UNK: oceans, belle, gloucester, rattus, bent, shusui, airplane, hormones,
# Nearest to many: midwestern, maud, oberlin, ssris, rosie, marrying, mak, disappear,
# Nearest to as: actinides, nights, tuvalu, wmo, aborigines, aden, piecewise, trumped,
# Nearest to zero: contemptuous, backdrop, publishing, saya, crypto, meticulous, supposition, stuarts,
# Nearest to nine: illegally, alder, alice, ulein, active, examination, drake, basotho,
# Nearest to a: earthquake, arnauld, sentry, grandchildren, silence, alkynes, synapses, levy,
# Nearest to this: wholly, blueprints, islands, lac, morita, masts, classifications, accordions,
# Nearest to has: periodical, labouring, hemispheres, fibers, bo, michell, besieging, png,
# Nearest to was: salisbury, alessandro, marino, glossary, gaiman, arran, artistry, proceed,
# Nearest to be: gaiman, mantua, oleg, granting, cherries, minivan, nowell, pattern,
# Nearest to who: linearly, passages, apotheosis, mandola, principalities, nothingness, advise, dardanelles,
# Nearest to when: bone, jass, mascarenes, winer, generators, verdicts, nadezhda, prequel,
# Nearest to not: schlick, privateers, jet, subgenus, nasa, burghers, abkhazian, kankan,
# Nearest to from: controls, asynchronous, tighten, disaffected, pym, ridiculous, elin, demoralized,
# Nearest to six: reasonably, equinoxes, shiloh, lowry, multiples, teachings, fork, believer,
# Nearest to often: katie, prefix, abnormally, lafayette, situations, waldheim, liner, nutritious,
# Average loss at step 2000: 4.368207
# Average loss at step 4000: 3.874534
# Average loss at step 6000: 3.798454
# Average loss at step 8000: 3.759396
# Average loss at step 10000: 3.618820
# Nearest to UNK: n, showcase, s, sidecar, and, partisan, hubris, babylon,
# Nearest to many: maud, midwestern, some, amending, several, marginalized, sqrt, mta,
# Nearest to as: harmless, through, democratization, sura, garnering, flames, cpes, enz,
# Nearest to zero: five, eight, four, six, seven, three, nine, two,
# Nearest to nine: eight, six, seven, five, four, zero, three, one,
# Nearest to a: the, this, begins, arnauld, militiamen, dorset, apokryphen, literals,
# Nearest to this: it, which, that, the, wettest, each, masts, a,
# Nearest to has: is, had, was, have, brittle, rs, ryukyu, alfa,
# Nearest to was: is, were, has, by, be, been, are, handed,
# Nearest to be: have, was, oleg, deviates, by, physiologist, were, gaiman,
# Nearest to who: also, linearly, apotheosis, he, passages, amalgamation, ci, beatings,
# Nearest to when: mascarenes, though, jass, verdicts, inhalants, but, winer, civilize,
# Nearest to not: they, thai, it, that, copyleft, still, outnumbered, there,
# Nearest to from: and, into, on, in, for, controls, by, camino,
# Nearest to six: seven, eight, five, four, three, nine, one, two,
# Nearest to often: also, fibre, warps, etched, axiom, douglass, gildas, brawl,
# Average loss at step 12000: 3.581769
# Average loss at step 14000: 3.615435
# Average loss at step 16000: 3.586245
# Average loss at step 18000: 3.569546
# Average loss at step 20000: 3.543438
# Nearest to UNK: marguerite, francia, arena, exemptions, consistently, kemal, smuggle, bridgewater,
# Nearest to many: some, several, these, all, maud, other, importance, midwestern,
# Nearest to as: by, hoofed, dishonest, walid, enterprise, entire, clarion, strategically,
# Nearest to zero: five, six, eight, four, nine, seven, three, two,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to a: the, dacia, any, dorset, pu, its, this, ozzy,
# Nearest to this: it, which, the, passy, that, he, mcdonald, masts,
# Nearest to has: had, have, was, is, charlotte, rs, pyle, brittle,
# Nearest to was: is, has, had, were, by, became, when, noxious,
# Nearest to be: have, been, are, refer, gaiman, explain, by, oleg,
# Nearest to who: he, linearly, also, they, that, apotheosis, there, ci,
# Nearest to when: though, if, after, where, mascarenes, was, while, during,
# Nearest to not: thai, generally, it, still, copyleft, they, walken, also,
# Nearest to from: into, by, in, across, pym, under, on, controls,
# Nearest to six: four, five, seven, eight, nine, three, zero, two,
# Nearest to often: commonly, usually, also, generally, sometimes, gildas, fibre, now,
# Average loss at step 22000: 3.527687
# Average loss at step 24000: 3.441997
# Average loss at step 26000: 3.417894
# Average loss at step 28000: 3.474566
# Average loss at step 30000: 3.406497
# Nearest to UNK: chop, angelos, vfr, mandolin, additions, icd, salle, serb,
# Nearest to many: some, several, these, all, those, other, most, various,
# Nearest to as: through, brimstone, because, when, hoofed, airships, temporary, arabia,
# Nearest to zero: five, six, eight, nine, four, two, seven, three,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to a: the, another, this, vengeance, electroweak, each, blends, dacia,
# Nearest to this: it, which, passy, the, each, a, masts, some,
# Nearest to has: had, have, is, was, charlotte, having, ryukyu, nanda,
# Nearest to was: is, had, were, has, became, been, began, be,
# Nearest to be: been, have, refer, is, become, are, heorot, allow,
# Nearest to who: he, they, linearly, which, sacks, also, seemingly, ci,
# Nearest to when: if, though, where, after, since, while, mascarenes, through,
# Nearest to not: they, it, thai, hypersonic, copyleft, harding, we, still,
# Nearest to from: into, in, between, through, camino, cyclopedia, across, hellenes,
# Nearest to six: seven, eight, five, four, nine, two, three, zero,
# Nearest to often: commonly, sometimes, generally, now, usually, also, always, there,
# Average loss at step 32000: 3.419622
# Average loss at step 34000: 3.440837
# Average loss at step 36000: 3.366242
# Average loss at step 38000: 3.492602
# Average loss at step 40000: 3.437493
# Nearest to UNK: insoluble, spitfire, idleness, arena, milder, sarcasm, powerplant, com,
# Nearest to many: some, several, these, all, other, various, both, those,
# Nearest to as: when, by, amd, clarion, for, brimstone, is, painful,
# Nearest to zero: five, four, two, six, eight, nine, three, seven,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to a: another, the, any, enough, dacia, spa, talkin, accidentals,
# Nearest to this: which, it, the, that, some, passy, our, masts,
# Nearest to has: had, have, was, is, fives, since, pyle, ryukyu,
# Nearest to was: is, were, has, had, became, been, s, be,
# Nearest to be: been, have, is, were, refer, by, was, become,
# Nearest to who: he, they, she, linearly, ci, which, sacks, shipwrecked,
# Nearest to when: if, though, while, after, although, where, during, before,
# Nearest to not: still, copyleft, they, it, actually, frustrating, thai, mascarene,
# Nearest to from: into, through, for, in, under, across, substantial, pym,
# Nearest to six: eight, seven, nine, five, four, three, two, zero,
# Nearest to often: commonly, sometimes, now, usually, generally, always, also, widely,
# Average loss at step 42000: 3.425590
# Average loss at step 44000: 3.272792
# Average loss at step 46000: 3.409712
# Average loss at step 48000: 3.430291
# Average loss at step 50000: 3.434607
# Nearest to UNK: l, gloucester, j, nucleosome, serge, i, milder, buffet,
# Nearest to many: some, several, these, various, those, all, both, certain,
# Nearest to as: brimstone, painful, define, novum, aquaculture, vaults, became, fulfil,
# Nearest to zero: five, eight, six, nine, four, seven, three, two,
# Nearest to nine: eight, seven, six, four, zero, five, three, two,
# Nearest to a: another, the, illustrated, any, no, dripping, celestines, randy,
# Nearest to this: which, it, passy, masts, occitan, dagestan, that, another,
# Nearest to has: had, have, was, is, since, pyle, fives, brahmin,
# Nearest to was: is, were, had, has, became, been, when, began,
# Nearest to be: been, have, is, refer, prove, being, were, become,
# Nearest to who: he, which, she, linearly, they, laurie, sacks, holt,
# Nearest to when: if, though, after, while, before, where, although, during,
# Nearest to not: still, copyleft, actually, they, walken, never, frustrating, outnumbered,
# Nearest to from: into, across, in, through, nica, around, pym, denslow,
# Nearest to six: seven, eight, four, five, nine, three, zero, two,
# Nearest to often: sometimes, commonly, usually, now, generally, also, widely, always,
# Average loss at step 52000: 3.453594
# Average loss at step 54000: 3.432314
# Average loss at step 56000: 3.404048
# Average loss at step 58000: 3.283535
# Average loss at step 60000: 3.377911
# Nearest to UNK: instinctively, et, n, friedrich, gloucester, l, racer, v,
# Nearest to many: some, several, these, all, both, those, various, such,
# Nearest to as: when, by, became, amines, aquaculture, like, amd, including,
# Nearest to zero: five, seven, nine, six, eight, four, three, two,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to a: another, the, roald, no, any, illustrated, dorset, crabbe,
# Nearest to this: which, it, another, passy, itself, cursive, that, masts,
# Nearest to has: had, have, is, was, ryukyu, proletarian, since, fives,
# Nearest to was: is, were, had, has, became, been, be, when,
# Nearest to be: been, become, have, is, was, prove, refer, were,
# Nearest to who: which, he, also, she, they, there, laurie, often,
# Nearest to when: if, though, after, before, while, although, because, where,
# Nearest to not: still, actually, copyleft, almost, thai, they, walken, never,
# Nearest to from: through, into, across, in, during, by, towards, pym,
# Nearest to six: eight, five, seven, four, nine, three, zero, two,
# Nearest to often: sometimes, commonly, usually, generally, now, frequently, always, widely,
# Average loss at step 62000: 3.439482
# Average loss at step 64000: 3.362597
# Average loss at step 66000: 3.341469
# Average loss at step 68000: 3.387180
# Average loss at step 70000: 3.369438
# Nearest to UNK: broth, et, messy, pregnancies, waterways, recharge, sprinkling, routines,
# Nearest to many: some, several, both, these, various, most, all, those,
# Nearest to as: like, by, after, in, vaults, teh, bat, idiosyncratic,
# Nearest to zero: five, four, seven, six, nine, eight, three, two,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to a: another, any, crabbe, dacia, no, the, brainfuck, resolutions,
# Nearest to this: which, it, cursive, another, the, passy, masts, mandela,
# Nearest to has: had, have, was, is, fives, ryukyu, since, pyle,
# Nearest to was: is, became, had, has, were, jdf, be, been,
# Nearest to be: been, have, become, was, prove, is, being, refer,
# Nearest to who: they, which, he, laurie, she, often, holt, also,
# Nearest to when: if, before, after, while, because, although, though, where,
# Nearest to not: still, actually, never, walken, generally, copyleft, they, thai,
# Nearest to from: across, into, through, during, in, storytelling, sorbonne, pym,
# Nearest to six: seven, eight, nine, four, five, three, zero, two,
# Nearest to often: sometimes, usually, commonly, now, generally, always, also, frequently,
# Average loss at step 72000: 3.404632
# Average loss at step 74000: 3.388648
# Average loss at step 76000: 3.348351
# Average loss at step 78000: 3.236374
# Average loss at step 80000: 3.367179
# Nearest to UNK: id, ullman, playstation, katana, serb, cno, references, et,
# Nearest to many: some, several, various, both, those, these, most, all,
# Nearest to as: warne, by, painful, when, like, polysaccharide, heaviside, including,
# Nearest to zero: five, seven, six, four, eight, nine, three, two,
# Nearest to nine: seven, eight, six, five, four, zero, three, two,
# Nearest to a: another, any, resolutions, the, dripping, every, uncommonly, this,
# Nearest to this: which, it, another, the, some, what, there, that,
# Nearest to has: had, have, is, was, since, nanda, makes, ryukyu,
# Nearest to was: is, were, has, had, became, irt, be, although,
# Nearest to be: become, been, is, refer, have, being, prove, was,
# Nearest to who: he, they, laurie, she, which, antidepressants, never, still,
# Nearest to when: if, where, though, while, after, because, although, before,
# Nearest to not: actually, still, never, dismantled, copyleft, outnumbered, occasionally, walken,
# Nearest to from: through, into, across, during, in, cyclopedia, suffixed, sampras,
# Nearest to six: seven, four, five, eight, nine, three, zero, two,
# Nearest to often: usually, sometimes, commonly, generally, now, typically, also, always,
# Average loss at step 82000: 3.296882
# Average loss at step 84000: 3.340965
# Average loss at step 86000: 3.342569
# Average loss at step 88000: 3.317789
# Average loss at step 90000: 3.232077
# Nearest to UNK: writer, van, screech, novelist, musician, martin, friedrich, elle,
# Nearest to many: some, several, various, both, these, all, those, most,
# Nearest to as: vaults, clover, hoofed, aquaculture, thermometers, for, consecutively, pompeius,
# Nearest to zero: five, six, seven, four, nine, eight, two, three,
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to a: another, the, dripping, resolutions, dorset, fibrillation, inducted, motile,
# Nearest to this: it, which, another, passy, the, leben, each, cursive,
# Nearest to has: had, have, is, was, since, fives, ryukyu, hildebrand,
# Nearest to was: is, had, were, became, has, been, although, kazimierz,
# Nearest to be: become, been, were, prove, have, being, refer, vma,
# Nearest to who: which, laurie, often, also, he, she, hearne, still,
# Nearest to when: if, after, while, before, though, where, although, during,
# Nearest to not: actually, never, generally, copyleft, still, t, walken, soho,
# Nearest to from: through, across, into, nica, in, during, after, until,
# Nearest to six: eight, seven, four, five, nine, three, zero, two,
# Nearest to often: usually, sometimes, commonly, generally, now, typically, frequently, always,
# Average loss at step 92000: 2.737315
# Average loss at step 94000: 3.098611
# Average loss at step 96000: 3.064655
# Average loss at step 98000: 3.220868
# Average loss at step 100000: 3.278709
# Nearest to UNK: neutral, balmoral, green, belle, cumann, philadelphia, lopez, san,
# Nearest to many: some, several, various, both, these, those, all, most,
# Nearest to as: warne, monmouthshire, hoofed, heartbeat, cellars, interchangeably, make, including,
# Nearest to zero: five, six, eight, four, seven, nine, three, two,
# Nearest to nine: eight, seven, six, four, five, zero, three, births,
# Nearest to a: another, the, dacia, inducted, any, this, every, crabbe,
# Nearest to this: which, it, the, another, leben, passy, fer, some,
# Nearest to has: had, have, is, was, although, fives, since, includes,
# Nearest to was: is, became, had, has, been, although, were, be,
# Nearest to be: become, been, have, prove, refer, is, being, was,
# Nearest to who: laurie, often, he, which, still, also, maududi, linearly,
# Nearest to when: if, though, while, where, before, after, although, because,
# Nearest to not: actually, never, still, generally, copyleft, t, dismantled, only,
# Nearest to from: through, across, into, in, nica, asynchronous, towards, uucp,
# Nearest to six: seven, five, eight, four, nine, three, zero, two,
# Nearest to often: usually, sometimes, commonly, generally, now, frequently, also, always,

# %%
print(final_embeddings[0])
# Out:
# [ 0.1077885  -0.03715329 -0.03542503  0.00246435 -0.09683713 -0.05856085
#   0.10702647 -0.08802266  0.0867431  -0.08122884  0.04159569 -0.08488789
#  -0.01186155  0.02610599  0.04100858  0.08922653  0.11120582  0.101988
#  -0.11366175 -0.06265495 -0.03251841 -0.0927361   0.04544103 -0.05926955
#  -0.02049969  0.01867076 -0.00616882  0.07111719 -0.07402456  0.03096567
#   0.078337    0.03526927  0.03852946  0.18782653 -0.03725789  0.10955762
#   0.14740002 -0.14680023  0.04360472  0.09038604 -0.13229799  0.05255344
#  -0.13081305  0.14131472 -0.00246912 -0.06174069 -0.1221372   0.01461082
#  -0.02591807  0.08199006  0.05876394  0.07493401  0.07707072  0.06335063
#   0.13578281 -0.02681805  0.05007719 -0.03903464  0.08501133 -0.16498932
#   0.11115384 -0.01626523 -0.08977766  0.09917726  0.18835874  0.0124554
#  -0.03556841 -0.00388116 -0.05553239 -0.11747533  0.08370302 -0.2045854
#   0.07766989 -0.02308826 -0.00152899 -0.12082966 -0.02610104  0.11864779
#  -0.19903472 -0.01431113  0.00834359 -0.03021232  0.08560938 -0.04907104
#  -0.17159893 -0.14208965  0.06758557 -0.02849134  0.01242499 -0.12736671
#   0.01553797 -0.15609214 -0.015332    0.00906727  0.04687013  0.15711972
#  -0.08834195 -0.04488344  0.03212032  0.0721281   0.14471963 -0.07417201
#   0.01085346 -0.03335972  0.06707225 -0.12203816 -0.07591812 -0.12757418
#   0.01527304 -0.07756752 -0.04132612  0.17089511  0.01806485  0.20339964
#  -0.12179074 -0.09158938  0.09198378  0.06180859 -0.04010664  0.01669885
#  -0.04763397  0.03123646  0.12029703  0.09054247  0.01222232  0.00283026
#   0.02397309 -0.10454028]

# %%
print(np.sum(np.square(final_embeddings[0])))
# Out:
# 1.0

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
"""Problem An alternative to skip-gram is another Word2Vec model"""
""" called CBOW (Continuous Bag of Words). In the CBOW model, """
"""instead of predicting a context word from a word vector, you"""
""" predict a word from the sum of all the word vectors in its context."""
""" Implement and evaluate a CBOW model trained on the text8 dataset."""

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.290545
# Nearest to by: catalana, chicks, jozef, gdi, conquests, sarabande, psalms, diversifying,
# Nearest to or: concretely, jettisoned, irda, boris, opposing, bah, puente, nun,
# Nearest to had: compost, breakfast, inciting, coefficient, interrogative, frustration, alton, wetlands,
# Nearest to american: faustina, abc, ais, dumplings, remoteness, fano, incidents, rancho,
# Nearest to from: invertible, mauritian, dunham, acrylic, focussed, dumplings, maximized, worship,
# Nearest to years: visuals, counterintuitive, lamarckian, abiding, sessions, goldwater, bokassa, menelaus,
# Nearest to known: lemnos, burgundians, concede, zoster, heavier, dbv, reliever, undefined,
# Nearest to they: mater, sofia, umbrella, scudetto, gaddis, pesos, hetfield, lactose,
# Nearest to new: nta, physicalism, deut, methionine, putative, cathodes, mclaughlin, qcd,
# Nearest to people: cafes, witte, sentiment, intentionality, decayed, menial, aonb, yggdrasil,
# Nearest to have: multi, fascinating, hittite, senna, bankers, itanium, promoting, reactions,
# Nearest to for: commentators, duchy, excitement, cline, machen, beef, kingpin, ustinov,
# Nearest to he: sentinels, botham, ewart, ranging, seizes, oic, weak, solferino,
# Nearest to other: acrobat, wasp, gustloff, infinitive, temple, universal, shapes, peculiarity,
# Nearest to also: statuette, antisemitism, brythonic, vermeer, aikman, dagda, agency, participant,
# Nearest to would: libel, alleys, maaouya, davey, convection, gian, commemorate, acknowledgment,
# Average loss at step 2000: 9.354464
# Average loss at step 4000: 5.513449
# Average loss at step 6000: 5.956174
# Average loss at step 8000: 4.238968
# Average loss at step 10000: 4.108224
# Nearest to by: who, daoxuan, musket, conquests, waterline, newly, amadeus, lumberjack,
# Nearest to or: than, and, quarried, counterexample, asclepius, paulette, hani, forcible,
# Nearest to had: has, have, was, were, would, downside, fouling, modernizing,
# Nearest to american: regia, rejoined, eg, curses, rely, fatima, austrian, hyperinsulinism,
# Nearest to from: chorded, into, dravidians, inputs, and, through, bassoon, admittedly,
# Nearest to years: replicators, months, zf, looksmart, enco, abiding, amphetamine, candidate,
# Nearest to known: such, used, referred, available, well, fuels, deeds, dbv,
# Nearest to they: he, we, forks, there, you, expect, seu, boac,
# Nearest to new: cathodes, confuse, habitat, mtv, unimportant, larissa, amoebae, distorting,
# Nearest to people: vanquished, men, paragraphs, hewitt, jacobian, propaganda, continued, grapefruit,
# Nearest to have: has, had, advising, gunto, mulberry, be, benches, having,
# Nearest to for: of, with, receptions, morningside, matth, blackhawks, partito, slovenia,
# Nearest to he: she, it, who, they, capybaras, liquefied, seine, ewart,
# Nearest to other: these, various, different, hostels, some, lighter, their, jeff,
# Nearest to also: moli, enshrined, swap, embryo, donkey, still, which, dirham,
# Nearest to would: will, can, may, could, must, should, did, to,
# Average loss at step 12000: 3.887576
# Average loss at step 14000: 4.015343
# Average loss at step 16000: 3.671726
# Average loss at step 18000: 3.790327
# Average loss at step 20000: 3.383412
# Nearest to by: when, with, recognise, conquests, eases, galloway, usemodwiki, into,
# Nearest to or: and, smp, than, movers, balancing, holyoke, abruptly, jutland,
# Nearest to had: has, have, having, was, romanorum, somerville, encha, would,
# Nearest to american: kensington, growths, regia, fatima, sutcliffe, international, rejoined, segmental,
# Nearest to from: into, through, explaining, risen, dravidians, delgado, gracefully, electroplating,
# Nearest to years: days, months, replicators, year, minutes, times, enco, syndicate,
# Nearest to known: referred, considered, served, such, available, gumby, regarded, described,
# Nearest to they: you, there, gases, we, sugarcane, feynman, he, antares,
# Nearest to new: montesquieu, unimportant, mtv, unidentified, nader, stormed, cathodes, recreating,
# Nearest to people: list, you, those, counterbalance, vanquished, arsenate, facade, paragraphs,
# Nearest to have: has, had, having, are, be, palpatine, produce, incendiary,
# Nearest to for: synthesizers, against, of, whitaker, matth, handily, since, receptions,
# Nearest to he: she, it, they, who, marines, dur, chooses, lillard,
# Nearest to other: various, different, these, both, those, harford, local, many,
# Nearest to also: below, still, often, which, when, commonly, clayton, wretched,
# Nearest to would: will, could, may, can, must, should, might, did,
# Average loss at step 22000: 3.557890
# Average loss at step 24000: 3.415041
# Average loss at step 26000: 3.518588
# Average loss at step 28000: 3.424459
# Average loss at step 30000: 3.368444
# Nearest to by: employs, usemodwiki, minster, musket, psalms, when, buch, milligrams,
# Nearest to or: and, jutland, than, spee, apprentice, sava, unnatural, geometrical,
# Nearest to had: has, have, having, was, could, gave, nfs, shehri,
# Nearest to american: mexican, undergraduate, vicente, kalinga, grace, korea, alexander, exporter,
# Nearest to from: into, through, gracefully, within, in, since, during, until,
# Nearest to years: days, months, year, zf, replicators, times, decades, minutes,
# Nearest to known: referred, used, described, defined, considered, available, served, seen,
# Nearest to they: we, you, he, mathilde, she, there, these, rented,
# Nearest to new: mtv, andhra, almighty, unimportant, old, localization, flatter, shan,
# Nearest to people: men, jews, americans, countries, students, figures, those, supporters,
# Nearest to have: has, had, having, include, produce, contain, chasm, bmj,
# Nearest to for: against, synthesizers, after, lorne, through, sensitivity, lovecraftian, annulment,
# Nearest to he: she, it, they, depriving, there, americanized, pinnacles, who,
# Nearest to other: different, those, various, smaller, these, several, harford, erhard,
# Nearest to also: below, still, often, now, which, psycho, battalions, sometimes,
# Nearest to would: could, may, can, must, might, should, did, will,
# Average loss at step 32000: 3.151900
# Average loss at step 34000: 3.336192
# Average loss at step 36000: 3.394143
# Average loss at step 38000: 3.241834
# Average loss at step 40000: 3.325810
# Nearest to by: when, psalms, amadeus, usemodwiki, minster, wellcome, mgm, conquests,
# Nearest to or: and, than, while, daredevil, resolver, spee, etc, heralds,
# Nearest to had: has, have, having, were, was, gave, saw, could,
# Nearest to american: america, british, canadian, pstn, aspirant, savers, international, philippines,
# Nearest to from: through, across, into, including, within, gracefully, during, before,
# Nearest to years: days, months, decades, year, minutes, replicators, zf, times,
# Nearest to known: referred, used, described, defined, such, seen, considered, regarded,
# Nearest to they: she, we, you, i, he, unions, sugarcane, rationalists,
# Nearest to new: mtv, andhra, japh, few, formal, recreated, costanza, unimportant,
# Nearest to people: men, those, members, jews, players, children, them, students,
# Nearest to have: had, has, having, palpatine, contain, produce, include, be,
# Nearest to for: like, while, cardiff, outside, chives, using, than, cappella,
# Nearest to he: it, they, she, shelf, inherently, americanized, who, surged,
# Nearest to other: smaller, various, these, many, different, castillian, including, hostels,
# Nearest to also: still, below, now, which, usually, often, sometimes, pendragon,
# Nearest to would: could, may, must, might, should, can, will, cannot,
# Average loss at step 42000: 3.295953
# Average loss at step 44000: 3.238788
# Average loss at step 46000: 3.213880
# Average loss at step 48000: 3.114652
# Average loss at step 50000: 3.167496
# Nearest to by: psalms, minster, amadeus, have, analgesic, under, witted, favorably,
# Nearest to or: and, than, sitar, pell, melanesia, without, smp, reputations,
# Nearest to had: has, have, having, was, gave, saw, magnified, requires,
# Nearest to american: british, canadian, australian, savers, jim, sutcliffe, jdk, fansite,
# Nearest to from: through, into, across, within, hizballah, during, in, employers,
# Nearest to years: months, days, decades, year, minutes, times, weeks, hours,
# Nearest to known: referred, used, seen, defined, described, sold, such, opposed,
# Nearest to they: you, we, there, he, she, abt, sugarcane, seeds,
# Nearest to new: different, nader, full, costanza, previous, psoriasis, separate, specific,
# Nearest to people: men, players, those, members, children, individuals, fans, supporters,
# Nearest to have: had, has, having, contain, produce, require, were, palpatine,
# Nearest to for: against, synthesizers, of, including, annulment, matth, nez, without,
# Nearest to he: she, it, they, who, shelf, inherently, investigations, branko,
# Nearest to other: individual, various, their, communication, lied, amazing, crypt, cardiff,
# Nearest to also: still, below, now, disambiguation, which, usually, often, actually,
# Nearest to would: will, could, may, might, should, can, must, cannot,
# Average loss at step 52000: 3.205076
# Average loss at step 54000: 3.180922
# Average loss at step 56000: 2.986865
# Average loss at step 58000: 3.107931
# Average loss at step 60000: 3.144531
# Nearest to by: minster, conquests, employs, wellcome, reflectance, initially, including, against,
# Nearest to or: than, and, aurangzeb, bix, coptic, soc, furnishes, yiddish,
# Nearest to had: has, have, having, saw, gave, was, gives, took,
# Nearest to american: america, canadian, international, australian, reformer, noll, japanese, materialised,
# Nearest to from: into, gracefully, throttle, within, giotto, over, neuralgia, delgado,
# Nearest to years: months, decades, days, minutes, weeks, times, hours, centuries,
# Nearest to known: referred, seen, defined, described, used, regarded, opposed, such,
# Nearest to they: we, he, you, there, she, mathilde, federally, others,
# Nearest to new: psoriasis, labors, different, localization, peaceful, old, mcenroe, specific,
# Nearest to people: players, those, languages, speakers, americans, members, individuals, seats,
# Nearest to have: had, having, has, require, contain, produce, refer, allow,
# Nearest to for: pre, cardiff, cappella, rump, bakker, chives, national, kalinga,
# Nearest to he: she, it, they, who, patan, inherently, roth, shelf,
# Nearest to other: various, certain, individual, many, multiple, different, smaller, substrates,
# Nearest to also: below, often, sometimes, disambiguation, still, usually, now, never,
# Nearest to would: will, could, might, should, may, must, can, cannot,
# Average loss at step 62000: 3.115073
# Average loss at step 64000: 3.001486
# Average loss at step 66000: 3.042113
# Average loss at step 68000: 3.092851
# Average loss at step 70000: 3.082329
# Nearest to by: minster, initially, employs, analgesic, bunsen, usemodwiki, psalms, for,
# Nearest to or: and, than, bix, while, incompatibilities, but, ellesmere, sixty,
# Nearest to had: has, have, having, was, gave, magnified, took, spoke,
# Nearest to american: british, australian, canadian, america, elbl, marlene, international, undone,
# Nearest to from: into, through, before, since, across, within, booking, throttle,
# Nearest to years: months, decades, centuries, weeks, days, year, minutes, season,
# Nearest to known: referred, defined, described, seen, viewed, understood, opposed, served,
# Nearest to they: we, you, he, there, mathilde, she, renormalization, federally,
# Nearest to new: different, beneficiaries, larissa, algiers, special, andhra, expatriates, almighty,
# Nearest to people: players, men, them, americans, speakers, person, children, students,
# Nearest to have: had, has, having, contain, require, refer, allow, produce,
# Nearest to for: of, after, matth, synthesizers, without, against, oceanography, damien,
# Nearest to he: she, it, they, who, shelf, americanized, inherently, already,
# Nearest to other: various, older, rather, smaller, more, both, those, substrates,
# Nearest to also: below, disambiguation, now, still, never, sometimes, often, subsequently,
# Nearest to would: will, could, might, should, must, may, can, cannot,
# Average loss at step 72000: 3.047938
# Average loss at step 74000: 2.977813
# Average loss at step 76000: 3.064046
# Average loss at step 78000: 3.080133
# Average loss at step 80000: 2.928478
# Nearest to by: conquests, analgesic, lumberjack, who, employs, without, bunsen, usemodwiki,
# Nearest to or: and, than, sindhu, kahane, klondike, soc, reputations, haggis,
# Nearest to had: has, have, having, was, includes, gave, requires, could,
# Nearest to american: america, australian, canadian, british, german, japanese, international, irish,
# Nearest to from: through, into, cabal, across, dravidians, gracefully, including, within,
# Nearest to years: decades, months, minutes, days, weeks, centuries, times, hours,
# Nearest to known: referred, regarded, defined, served, understood, famous, described, used,
# Nearest to they: we, you, he, she, there, i, abt, mathilde,
# Nearest to new: different, special, specific, full, separate, almighty, andhra, nzwani,
# Nearest to people: players, men, others, americans, fans, jews, children, person,
# Nearest to have: had, has, having, contain, allow, provide, require, be,
# Nearest to for: during, while, synthesizers, thus, innuendo, devi, reichstag, soybeans,
# Nearest to he: she, it, they, americanized, who, rajah, roth, pinnacles,
# Nearest to other: various, smaller, more, dealing, lighter, different, both, rather,
# Nearest to also: sometimes, disambiguation, now, never, below, frequently, which, still,
# Nearest to would: could, will, might, should, must, may, cannot, can,
# Average loss at step 82000: 2.996422
# Average loss at step 84000: 2.943673
# Average loss at step 86000: 3.006166
# Average loss at step 88000: 3.028849
# Average loss at step 90000: 2.883774
# Nearest to by: via, analgesic, bunsen, lumberjack, initially, tango, without, mcgee,
# Nearest to or: and, though, but, whose, than, exalted, while, pickling,
# Nearest to had: has, have, having, was, could, shall, retains, requires,
# Nearest to american: australian, america, canadian, icelandic, international, irish, austrian, americans,
# Nearest to from: into, back, across, via, throttle, tortoise, bless, booking,
# Nearest to years: decades, months, days, minutes, weeks, centuries, year, generations,
# Nearest to known: referred, described, defined, understood, served, seen, opposed, used,
# Nearest to they: we, you, he, there, she, abt, it, shelf,
# Nearest to new: separate, specific, different, organize, single, gandhara, previous, nzwani,
# Nearest to people: men, jews, players, children, americans, readers, citizens, them,
# Nearest to have: had, has, having, contain, require, produce, allow, represent,
# Nearest to for: matth, innuendo, after, oceanography, walser, kurtosis, astrologically, against,
# Nearest to he: she, it, they, hannibal, yeltsin, fox, shelf, brahms,
# Nearest to other: various, fewer, others, multiple, lied, evaluating, dq, channeled,
# Nearest to also: still, disambiguation, which, never, below, sometimes, typically, now,
# Nearest to would: will, could, might, should, must, can, may, cannot,
# Average loss at step 92000: 2.943169
# Average loss at step 94000: 2.930408
# Average loss at step 96000: 2.747980
# Average loss at step 98000: 2.499596
# Average loss at step 100000: 2.767197
# Nearest to by: conquests, via, minster, thus, analgesic, employs, cooperatively, initially,
# Nearest to or: and, than, but, involving, though, incompatibilities, figuratively, azeotrope,
# Nearest to had: has, have, having, was, retains, requires, ve, shehri,
# Nearest to american: canadian, australian, english, irish, british, scottish, boyars, japanese,
# Nearest to from: into, across, through, toward, throttle, via, circa, without,
# Nearest to years: decades, months, weeks, year, hours, days, centuries, minutes,
# Nearest to known: referred, described, defined, seen, used, opposed, viewed, understood,
# Nearest to they: we, you, he, there, dumplings, she, resuming, abt,
# Nearest to new: luce, separate, montesquieu, old, gandhara, himachal, third, brisbane,
# Nearest to people: persons, children, men, speakers, students, residents, individuals, citizens,
# Nearest to have: had, has, contain, having, ve, require, produce, allow,
# Nearest to for: after, damien, keying, matth, gunto, oceanography, including, without,
# Nearest to he: she, it, they, hannibal, initially, who, there, shelf,
# Nearest to other: various, different, hostels, both, earlier, these, others, individual,
# Nearest to also: often, disambiguation, below, which, now, actually, never, currently,
# Nearest to would: could, will, might, must, should, may, can, did,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
